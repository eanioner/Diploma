# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
x = ["2010","2011", "2012", "2013","2014","2015","2016*","2017*", "2018*", "2019*"]
y = [0.97, 1.22, 1.4, 1.59, 1.87, 2.04, 2.22, 2.39, 2.55, 2.72]
plt.figure(figsize=(10,5))
sns.set_style("whitegrid")
sns.barplot(x,y,palette="Blues_d")
sns.axlabel(u"Год", u"Количество пользователей, млрд")

# %%
x = ["Facebook", "WhatsApp", "Facebook Messeger", "QQ", "WeChat", "QZone", "Tumblr", "Instagram", "Twitter", "Badu Tieba", "Skype", "Viber", "Sina Weibo", "LINE", "Snapchat", "yy", "VKontakte", "Pinterest", "BBM", "Linkedin", "Telegram"]
y = [1590, 1000, 900, 853, 697, 640, 555, 400, 320, 300, 300, 249, 222, 215, 200, 122, 100, 100, 100, 100, 100]
plt.figure(figsize=(10,8))
#sns.set_style("whitegrid")
sns.barplot(y,x,palette="Blues_d")
sns.axlabel(u'Количество пользователей, млн', u'Социальная сеть')
